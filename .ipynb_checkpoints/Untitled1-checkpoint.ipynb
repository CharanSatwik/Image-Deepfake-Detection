# %%
import sys
import sklearn
import tensorflow as tf

import cv2
import pandas as pd
import numpy as np

import plotly.graph_objs as go
from plotly.offline import iplot
from matplotlib import pyplot as plt

# %%
tf.test.is_gpu_available()
strategy = tf.distribute.MirroredStrategy()
print('DEVICES AVAILABLE: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# DEVICES AVAILABLE: 1

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
import os

def get_data():
    return pd.read_csv('metadata.csv')

# %%
meta=get_data()
meta.head()
# Out:
#         videoname  original_width  original_height label        original
# 0  aznyksihgl.mp4             129              129  FAKE  xnojggkrxt.mp4
# 1  gkwmalrvcj.mp4             129              129  FAKE  hqqmtxvbjj.mp4
# 2  lxnqzocgaq.mp4             223              217  FAKE  xjzkfqddyk.mp4
# 3  itsbtrrelv.mp4             186              186  FAKE  kqvepwqxfe.mp4
# 4  ddvgrczjno.mp4             155              155  FAKE  pluadmqqta.mp4

# %%
len(meta[meta.label=='FAKE']),len(meta[meta.label=='REAL'])
# Out:
# (79341, 16293)

# %%
real_df = meta[meta["label"] == "REAL"]
fake_df = meta[meta["label"] == "FAKE"]
sample_size = 42000
fake_df = fake_df.sample(sample_size, random_state=42)
sample_meta = pd.concat([real_df, fake_df])

# %%
from sklearn.model_selection import train_test_split

Train_set, Test_set = train_test_split(sample_meta,test_size=0.2,random_state=42,stratify=sample_meta['label'])
Train_set, Val_set  = train_test_split(Train_set,test_size=0.15,random_state=42,stratify=Train_set['label'])

# %%
Train_set.shape,Val_set.shape,Test_set.shape
# Out:
# ((39638, 5), (6996, 5), (11659, 5))

# %%
y = dict()

y[0] = []
y[1] = []

for set_name in (np.array(Train_set['label']), np.array(Val_set['label']), np.array(Test_set['label'])):
    y[0].append(np.sum(set_name == 'REAL'))
    y[1].append(np.sum(set_name == 'FAKE'))

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='REAL',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='FAKE',
    marker=dict(color='#ff3300'),
    opacity=0.7
)

data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)

fig = go.Figure(data, layout)
iplot(fig)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(15,15))

for cur, i in enumerate(Train_set.index[25:50]):
    plt.subplot(5, 5, cur + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    
    # Construct the image path
    videoname = Train_set.loc[i, 'videoname']
    img_path = 'faces_224/' + videoname[:-4] + '.jpg'
    
    # Print the image path for debugging
    print(f"Attempting to load image: {img_path}")
    
    # Read the image using OpenCV
    img = cv2.imread(img_path)
    
    # Check if image was successfully loaded
    if img is not None:
        # Convert image from BGR (OpenCV format) to RGB (Matplotlib format)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img_rgb)
    else:
        print(f"Warning: Image at {img_path} could not be loaded.")
        plt.imshow(np.zeros((224, 224, 3)))  # Display a black square in case of error
    
    # Set the label
    if Train_set.loc[i, 'label'] == 'FAKE':
        plt.xlabel('FAKE Image')
    else:
        plt.xlabel('REAL Image')

plt.show()
# Out:
# Attempting to load image: faces_224/bztifpciva.jpg
# Attempting to load image: faces_224/qkzugbahsa.jpg
# Attempting to load image: faces_224/tyvnebhivl.jpg
# Attempting to load image: faces_224/ajiyrjfyzp.jpg
# Attempting to load image: faces_224/cudjeshfcw.jpg
# Attempting to load image: faces_224/vlprdhtkdn.jpg
# Attempting to load image: faces_224/ksyyavokoz.jpg
# Attempting to load image: faces_224/badfzsekpa.jpg
# Attempting to load image: faces_224/uirbsagvgg.jpg
# Attempting to load image: faces_224/jmdylhjyzf.jpg
# Attempting to load image: faces_224/xfemsgumbe.jpg
# Attempting to load image: faces_224/phvoabhqqv.jpg
# Attempting to load image: faces_224/fedagjfkfa.jpg
# Attempting to load image: faces_224/kyseobpeim.jpg
# Attempting to load image: faces_224/swkyjuccjb.jpg
# Attempting to load image: faces_224/fsvqzxyvxz.jpg
# Attempting to load image: faces_224/bqqpqklcta.jpg
# Attempting to load image: faces_224/gufwnzmwli.jpg
# Attempting to load image: faces_224/sfwmfngbnx.jpg
# Attempting to load image: faces_224/oqugflbjso.jpg
# Attempting to load image: faces_224/xivovgwyhq.jpg
# Attempting to load image: faces_224/xuxiuacwuy.jpg
# Attempting to load image: faces_224/ssrztvkhdi.jpg
# Attempting to load image: faces_224/ksyvrepnua.jpg
# Attempting to load image: faces_224/msvydnlmxq.jpg

# %%
def retreive_dataset(set_name):
    images,labels=[],[]
    for (img, imclass) in zip(set_name['videoname'], set_name['label']):
        images.append(cv2.imread('faces_224'+img[:-4]+'.jpg'))
        if(imclass=='FAKE'):
            labels.append(1)
        else:
            labels.append(0)
    
    return np.array(images),np.array(labels)

# %%
X_train,y_train=retreive_dataset(Train_set)
X_val,y_val=retreive_dataset(Val_set)
X_test,y_test=retreive_dataset(Test_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 4
#       2 X_val,y_val=retreive_dataset(Val_set)
#       3 X_test,y_test=retreive_dataset(Test_set)
# ----> 4 X_train_tensor=tf.convert_to_tensor(X_train, dtype=tf.int64)
#       6 y_train_tensor=tf.convert_to_tensor(y_train, dtype=tf.int64)
#
# File F:\Anaconda\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File F:\Anaconda\Lib\site-packages\tensorflow\python\framework\constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %%
import tensorflow as tf
from functools import partial

tf.random.set_seed(42) 
DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same",
                        activation="relu", kernel_initializer="he_normal")

model = tf.keras.Sequential([
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[224, 224, 3]),
    tf.keras.layers.MaxPool2D(),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=64, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=1, activation="sigmoid")
])
# Out:
# F:\Anaconda\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.compile(loss="binary_crossentropy", optimizer="nadam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)                   │ (None, 224, 224, 64)        │           9,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_6 (Flatten)                  │ (None, 401408)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │      51,380,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 51,619,585 (196.91 MB)
#  Trainable params: 51,619,585 (196.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=5,batch_size=64,
                    validation_data=(X_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 history = model.fit(X_train, y_train, epochs=5,batch_size=64,
#       2                     validation_data=(X_val, y_val))
#
# File F:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File F:\Anaconda\Lib\site-packages\tensorflow\python\framework\constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type NoneType).
